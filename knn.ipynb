# %% [markdown]
# <a href="https://colab.research.google.com/github/MrParasmani/Projects/blob/main/knn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = [1,1,3,5,4,6,8,2,5,7]
y = [3,4,5,2,1,2,3,4,5,6]

classes = [0,0,0,1,0,1,0,1,1,1]

plt.scatter(x,y,c = classes)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.neighbors import KNeighborsClassifier
data = list(zip(x,y))
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(data,classes)
new_x = 8
new_y = 7
new_point = [(new_x,new_y)]
predict = knn.predict(new_point)
print(predict)
# Out:
# [1]

# %%
plt.scatter(x+[new_x],y+[new_y],c = classes + [predict])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
